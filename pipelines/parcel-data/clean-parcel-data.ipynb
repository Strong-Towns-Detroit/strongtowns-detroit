# %%
import pandas as pd

# %%
dataTypes = {
    "Taxpayer 2": "string",
    "Street Prefix": "string",
    "Parcel ID": "string",
    "ZIP Code": "string",
    "Landmap": "string",
    'Subdivision': 'string',
    "Local Historic District": "string",
    "Use Code Description": "string"
}

column_mapping = {
    'object_id': 'object_id',
    'Parcel ID': 'parcel_id',
    'Address': 'address',
    'ZIP Code': 'zip_code',
    'Taxpayer 1': 'taxpayer_1',
    'Taxpayer 2': 'taxpayer_2',
    'Taxpayer Address': 'taxpayer_address',
    'Taxpayer City': 'taxpayer_city',
    'Taxpayer State': 'taxpayer_state',
    'Taxpayer ZIP Code': 'taxpayer_zip_code',
    'Property Class': 'property_class',
    'Property Class Description': 'property_class_description',
    'Previous Property Class': 'previous_property_class',
    'Use Code': 'use_code',
    'Use Code Description': 'use_code_description',
    'Zoning District': 'zoning_district',
    'Year Built': 'year_built',
    'Building Style': 'building_style',
    'Building Count': 'building_count',
    'Total Floor Area': 'total_floor_area',
    'Tax Status': 'tax_status',
    'Tax Status Description': 'tax_status_description',
    'Previous Tax Status': 'previous_tax_status',
    'Assessed Value': 'assessed_value',
    'Previous Assessed Value': 'previous_assessed_value',
    'Taxable Value': 'taxable_value',
    'Previous Taxable Value': 'previous_taxable_value',
    'Principal Residence Exemption % Claimed': 'principal_residence_exemption_percent_claimed',
    'NEZ District': 'nez_district',
    'ECF Neighborhood': 'ecf_neighborhood',
    'Is Improved': 'is_improved',
    'Related Parcel ID': 'related_parcel_id',
    'Sale Date': 'sale_date',
    'Sale Price': 'sale_price',
    'Total Square Footage': 'total_square_footage',
    'Total Acreage': 'total_acreage',
    'Frontage': 'frontage',
    'Depth': 'depth',
    'Parcel Modified Date': 'parcel_modified_date',
    'Legal Description': 'legal_description',
    'Ward': 'ward',
    'Landmap': 'landmap',
    'Subdivision': 'subdivision',
    'Local Historic District': 'local_historic_district',
    'Neighborhood': 'neighborhood',
    'Council District': 'council_district',
    'Street Number': 'street_number',
    'Street Prefix': 'street_prefix',
    'Street Name': 'street_name',
    'ObjectId': 'object_id',
    'Shape__Area': 'shape_area',
    'Shape__Length': 'shape_length'
}

df = pd.read_csv('parcel-data.csv', dtype=dataTypes).rename(columns=column_mapping)
df.to_csv('parcel-data-cleaned.csv', index=False)
